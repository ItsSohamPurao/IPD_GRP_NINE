# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 90)
pd.set_option('display.max_rows', 90)

# %%
file_path = "/content/players_fifa22.csv"
df = pd.read_csv(file_path)

# %%
df.head(20)
# Out:
#         ID               Name                           FullName  Age  Height  \
# 0   158023           L. Messi                       Lionel Messi   34     170
# 1   188545     R. Lewandowski                 Robert Lewandowski   32     185
# 2    20801  Cristiano Ronaldo       C. Ronaldo dos Santos Aveiro   36     187
# 3   231747          K. Mbappé                      Kylian Mbappé   22     182
# 4   200389           J. Oblak                          Jan Oblak   28     188
# 5   192985       K. De Bruyne                    Kevin De Bruyne   30     181
# 6   190871          Neymar Jr         Neymar da Silva Santos Jr.   29     175
# 7   215914           N. Kanté                       N'Golo Kanté   30     168
# 8   202126            H. Kane                         Harry Kane   27     188
# 9   192448      M. ter Stegen              Marc-André ter Stegen   29     187
# 10  167495           M. Neuer                       Manuel Neuer   35     193
# ...

# %%
df.shape
# Out:
# (19260, 90)

# %%
df.duplicated().sum()
# Out:
# np.int64(104)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                       0
# Name                     0
# FullName                 0
# Age                      0
# Height                   0
# Weight                   0
# PhotoUrl                 0
# Nationality              0
# Overall                  0
# Potential                0
# Growth                   0
# TotalStats               0
# BaseStats                0
# Positions                0
# BestPosition             0
# Club                     0
# ValueEUR                 0
# WageEUR                  0
# ReleaseClause            0
# ClubPosition            76
# ContractUntil           76
# ClubNumber              76
# ClubJoined               0
# OnLoad                   0
# NationalTeam             0
# NationalPosition     18411
# NationalNumber       18411
# PreferredFoot            0
# IntReputation            0
# WeakFoot                 0
# SkillMoves               0
# AttackingWorkRate        0
# DefensiveWorkRate        0
# PaceTotal                0
# ...

# %%
def get_null_percentages(df, columns):
    result = {}
    for col in columns:
        if col in df.columns:
            null_count = df[col].isnull().sum()
            total_count = len(df)
            null_percentage = (null_count / total_count) * 100
            result[col] = round(null_percentage, 2)
        else:
            result[col] = "Column not found"

    return result

columns_to_check = ['ClubPosition','ContractUntil','ClubNumber','NationalPosition']

null_percentages = get_null_percentages(df, columns_to_check)

for column, percentage in null_percentages.items():
    if isinstance(percentage, float):
        print(f"{column}: {percentage}%")
    else:
        print(f"{column}: {percentage}")
# Out:
# ClubPosition: 0.4%
# ContractUntil: 0.4%
# ClubNumber: 0.4%
# NationalPosition: 96.11%

# %%
df.drop(['NationalPosition'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
columns_to_fill =  ['ClubPosition','ClubNumber','ContractUntil']
df[columns_to_fill].fillna(df[columns_to_fill].median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-573bf7f925d7> in <cell line: 0>()
#       1 columns_to_fill =  ['ClubPosition','ClubNumber','ContractUntil']
# ----> 2 df[columns_to_fill].fillna(df[columns_to_fill].median(), inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
# ...
